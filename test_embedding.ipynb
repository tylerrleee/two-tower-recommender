# %%
import numpy as np
import pandas as pd
from embedding_pipeline import EmbeddingPipeline
from feature_engineer import FeatureEngineer

# %%
df = pd.read_csv("./vso_ratataou_ace_mock_data.csv")
df.head()
# Out:
#                Name   Pronouns           UFL Email              Phone  \
# 0     Taylor Jarvis  they/them   daniel910@ufl.edu      (673)774-0860
# 1        Corey Knox    she/her  gabriel680@ufl.edu         1713894873
# 2        Mark Reyes  they/them    julie359@ufl.edu  (044)445-6922x353
# 3  Kathleen Ballard    she/her     tara913@ufl.edu       119.318.8215
# 4      Dawn Coleman  they/them   angela816@ufl.edu   931-155-4194x903
#
#       Socials  Year                   Major Other Orgs  Role (0=Big,1=Little)  \
# 0  @jeffrey63     0                 Finance        VSO                      1
# 1    @chris19     0  Mechanical Engineering        FSA                      1
# 2    @tracy38     0        Computer Science        VSO                      1
# 3    @james40     0                 Finance        AAA                      1
# 4   @joseph45     0            Data Science        HSA                      1
#
#    Preferred Littles  ...                   Favorite Food  \
# 0                NaN  ...  I would literally eat anything
# 1                NaN  ...                           Asian
# 2                NaN  ...             Greek/Mediterranean
# 3                NaN  ...             Greek/Mediterranean
# 4                NaN  ...                        American
#
#   EarlyBird/NightOwl (0=Early,1=Night)  Extroversion (1-5)  Good Advice (1-5)  \
# 0                                    1                   4                  4
# 1                                    0                   3                  3
# 2                                    1                   3                  3
# 3                                    0                   4                  4
# 4                                    1                   2                  2
#
#   Plans Style (1-5) Study Frequency (1-5) Gym Frequency (1-5)  \
# 0                 3                     3                   1
# 1                 3                     4                   2
# 2                 3                     3                   1
# 3                 1                     3                   1
# 4                 2                     4                   2
#
#   Spending Habits (1-5)         Friday Night  \
# 0                     3     gaming all night
# 1                     2     gaming all night
# 2                     5     gaming all night
# 3                     2     gaming all night
# 4                     1  dinner with friends
#
#                 Additional Info (Optional)
# 0  I love hanging out at Plaza of Americas
# 1  I love hanging out at Plaza of Americas
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 33 columns]

# %%
# load our criteria for applicant features
from config import RENAME_MAP, DEFAULT_CATEGORICALS, DEFAULT_NUMERICS, DEFAULT_PROFILE_TEXT
DEFAULT_PROFILE_TEXT
# Out:
# ['free_time',
#  'hobbies',
#  'self_description',
#  'icks',
#  'talk_for_hours_about',
#  'friday_night',
#  'additional_info']

# %%
# Initiate Feature engineer to standardize our applicant responses & data
FEATURE_ENGINE = FeatureEngineer(
                profile_text= DEFAULT_PROFILE_TEXT,
                categorical_fields= DEFAULT_CATEGORICALS,
                numeric_fields=DEFAULT_NUMERICS
)

# %%
df = FEATURE_ENGINE.rename_column(df)

# %%
transformed_features = FEATURE_ENGINE.fit_transform(df)
print("-------")
print("features includes:" , transformed_features.keys())
# Out:
# Fitting DataFrame...
# Finished Fitting.
# Fit Status:  True
# Transforming...
# Our current DataFrame                name   pronouns           ufl_email              phone  \
# 0     Taylor Jarvis  they/them   daniel910@ufl.edu      (673)774-0860
# 1        Corey Knox    she/her  gabriel680@ufl.edu         1713894873
# 2        Mark Reyes  they/them    julie359@ufl.edu  (044)445-6922x353
# 3  Kathleen Ballard    she/her     tara913@ufl.edu       119.318.8215
# 4      Dawn Coleman  they/them   angela816@ufl.edu   931-155-4194x903
#
#       socials year                   major other_orgs role preferred_littles  \
# 0  @jeffrey63    0                 Finance        VSO    1
# 1    @chris19    0  Mechanical Engineering        FSA    1
# 2    @tracy38    0        Computer Science        VSO    1
# 3    @james40    0                 Finance        AAA    1
# 4   @joseph45    0            Data Science        HSA    1
#
#    ... earlybird_nightowl extroversion good_advice plans_style  \
# 0  ...                  1          4.0         4.0         3.0
# 1  ...                  0          3.0         3.0         3.0
# 2  ...                  1          3.0         3.0         3.0
# 3  ...                  0          4.0         4.0         1.0
# 4  ...                  1          2.0         2.0         2.0
#
#   study_frequency gym_frequency spending_habits         friday_night  \
# 0             3.0           1.0             3.0     gaming all night
# 1             4.0           2.0             2.0     gaming all night
# 2             3.0           1.0             5.0     gaming all night
# 3             3.0           1.0             2.0     gaming all night
# 4             4.0           2.0             1.0  dinner with friends
#
#                            additional_info  \
# 0  I love hanging out at Plaza of Americas
# 1  I love hanging out at Plaza of Americas
# 2
# 3
# 4
#
#                                         profile_text
# 0  photography. traveling, music, movies. Ahead t...
# 1  photography. music, reading. Defense stage fal...
# 2  cooking. gaming. Seven hand across anything al...
# 3  traveling. traveling, photography. Situation d...
# 4  cooking. gym, photography. Crime area strategy...
#
# [5 rows x 34 columns]
# Finished Transforming.
# -------
# features includes: dict_keys(['profile_text', 'meta_features', 'index', 'raw_df'])

# %%
META_FEATURES = transformed_features['meta_features']
TEXT_EMBEDDINGS =transformed_features['profile_text'].to_numpy()

print("Meta Type: ", type(META_FEATURES))
print("Profile text Type: " , type(TEXT_EMBEDDINGS))
# Out:
# Meta Type:  <class 'numpy.ndarray'>
# Profile text Type:  <class 'numpy.ndarray'>

# %%
EMBEDDING_PIPELINE = EmbeddingPipeline(sbert_model_name='all-MiniLM-L6-v2')

# %%
combined_features = EMBEDDING_PIPELINE.combine_features(meta_features=transformed_features['meta_features'],
                                                        text_embeddings=transformed_features['profile_text'])
# Out:
# Combining text embeddings & meta features...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 combined_features = EMBEDDING_PIPELINE.combine_features(meta_features=transformed_features['meta_features'],
#       2                                                         text_embeddings=transformed_features['profile_text'])
#
# File ~/Documents/Coding/recommender-system-vso/two-tower-recommender/embedding_pipeline.py:77, in EmbeddingPipeline.combine_features(self, text_embeddings, meta_features)
#      74      raise ValueError("Mismatched entries between text embedding & meta features!")
#      76 # Cast precision type
# ---> 77 text_embed = text_embeddings.astype(self.precision)
#      78 meta       = meta.astype(self.precision)
#      79 combined   = np.concatenate(arrays=[text_embed, meta], axis=1)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/gstatsmcmc/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'photography. traveling, music, movies. Ahead ten civil theory fly ready skin against.. fashion trends. gaming all night. I love hanging out at Plaza of Americas'
